# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2
import datetime
#data = cv2.VideoCapture("/content/PEDIDOS YA_CHICO-TU MUNDO SE VOLVIO MAS DIGITAL Y P(COMERCIAL).wmv")
data = cv2.VideoCapture("/content/drive/MyDrive/ANEXOS_TESIS/5.videos de seguimiento ocular/videos/10.nacho1.mp4")
frames = data.get(cv2.CAP_PROP_FRAME_COUNT)
fps = int(data.get(cv2.CAP_PROP_FPS))
seconds = int(frames / fps)
video_time = str(datetime.timedelta(seconds=seconds))
print("duration in seconds:", seconds)
print("video time:", video_time)
seconds
# Out:
# duration in seconds: 30
# video time: 0:00:30
# 30

# %%
print(fps)
print(frames)
# Out:
# 25
# 750.0

# %% [markdown]
# Se debe chequear que todos sean de 25 fps si no es necesario cambiarlo, uno por uno, tal como se muestra acontinuacion

# %%
from moviepy.editor import *
clip = VideoFileClip(" ruta del video ")
clip.write_videofile("ruta del video ", fps=25)
# Out:
# Moviepy - Building video /content/drive/MyDrive/ANEXOS_TESIS/5.videos de seguimiento ocular/videos/1.edgar1.mp4.
# Moviepy - Writing video /content/drive/MyDrive/ANEXOS_TESIS/5.videos de seguimiento ocular/videos/1.edgar1.mp4
# t:   0%|          | 0/748 [00:00<?, ?it/s, now=None]WARNING:py.warnings:/usr/local/lib/python3.10/dist-packages/moviepy/video/io/ffmpeg_reader.py:123: UserWarning: Warning: in file /content/drive/MyDrive/ANEXOS_TESIS/5.videos de seguimiento ocular/videos/1.edgar1.mp4, 2764800 bytes wanted but 0 bytes read,at frame 4/749, at time 0.16/29.92 sec. Using the last valid frame instead.
#   warnings.warn("Warning: in file %s, "%(self.filename)+
#
# ...
