# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# traer imagenes de forma ordenada
from natsort import natsorted
from pathlib import Path
full_list =natsorted([ archivo.as_posix() for archivo in Path('/content/drive/MyDrive/ANEXOS_TESIS/3.deteccion_de_marca/yolov5/imagenesm').glob('*')])
#print(full_list)

# %%
full_list[164]
# Out:
# '/content/drive/MyDrive/ANEXOS_TESIS/3.deteccion_de_marca/yolov5/imagenesm/165.jpg'

# %%
from pathlib import Path
from skimage import io
image=[]
index=0
for index in range(164):
    full_list =natsorted([ archivo.as_posix() for archivo in Path('/content/drive/MyDrive/ANEXOS_TESIS/3.deteccion_de_marca/yolov5/imagenesm').glob('*')])
    imagen=io.imread(full_list[index])
    index += 1
    image.append(imagen)

# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path
from skimage import io

plt.imshow(image[0])

# %%
import cv2
import imutils
from skimage import io
image2=[]
index=0
for index in range(164):
  imagen=cv2.cvtColor(image[index], cv2.COLOR_RGB2GRAY)
  index += 1
  image2.append(imagen)

# %%
plt.imshow(image2[0])
print(image2[0].shape)
# Out:
# (153, 202)

# %%
# Cargar la imagen
imagen = image[0]

# Extraer los canales de color
red_channel = imagen[:, :, 0]  # El canal rojo está en la primera dimensión (0)

# Crear una imagen solo con el canal rojo
imagen_roja = np.zeros_like(imagen)
imagen_roja[:, :, 0] = red_channel  # Establecer el canal rojo

# Mostrar la imagen en rojo
plt.imshow(imagen_roja)
plt.axis('off')  # Para quitar los ejes
plt.show()

# %%
# Cargar la imagen
imagen = image[0]

# Extraer los canales de color
red_channel = imagen[:, :, 1]  # El canal rojo está en la primera dimensión (0)

# Crear una imagen solo con el canal rojo
imagen_roja = np.zeros_like(imagen)
imagen_roja[:, :, 1] = red_channel  # Establecer el canal rojo

# Mostrar la imagen en rojo
plt.imshow(imagen_roja)
plt.axis('off')  # Para quitar los ejes
plt.show()

# %%
# Cargar la imagen
imagen = image[0]

# Extraer los canales de color
red_channel = imagen[:, :, 2]  # El canal rojo está en la primera dimensión (0)

# Crear una imagen solo con el canal rojo
imagen_roja = np.zeros_like(imagen)
imagen_roja[:, :, 2] = red_channel  # Establecer el canal rojo

# Mostrar la imagen en rojo
plt.imshow(imagen_roja)
plt.axis('off')  # Para quitar los ejes
plt.show()

# %%
print(image2[1].shape[0])
# Out:
# 157

# %%
listan = []

for x in range(len(image2)):
    rows, cols = image2[x].shape

    current_image_values = []
    for fila in range(rows):
        for columna in range(cols):
            pixel_value = int(str(image2[x][fila, columna]))
            current_image_values.append(pixel_value)

    listan.append(current_image_values)

# %%
listar = []

for x in range(len(image)):
    rows, cols, _ = image[x].shape  # La tercera dimensión (_ en este caso) es el canal

    current_image_values = []
    for fila in range(rows):
        for columna in range(cols):
            pixel_value = int(str(image[x][fila, columna, 0]))  # Obtén el valor del primer canal
            current_image_values.append(pixel_value)

    listar.append(current_image_values)

# %%
listag = []

for x in range(len(image)):
    rows, cols, _ = image[x].shape  # La tercera dimensión (_ en este caso) es el canal

    current_image_values = []
    for fila in range(rows):
        for columna in range(cols):
            pixel_value = int(str(image[x][fila, columna, 1]))  # Obtén el valor del primer canal
            current_image_values.append(pixel_value)

    listag.append(current_image_values)

# %%
listab = []

for x in range(len(image)):
    rows, cols, _ = image[x].shape  # La tercera dimensión (_ en este caso) es el canal

    current_image_values = []
    for fila in range(rows):
        for columna in range(cols):
            pixel_value = int(str(image[x][fila, columna, 2]))  # Obtén el valor del primer canal
            current_image_values.append(pixel_value)

    listab.append(current_image_values)

# %%
from statistics import mean
from statistics import median
from statistics import mode

m_negro=[]
me_negro=[]
mo_negro=[]
m_azul=[]
me_azul=[]
mo_azul=[]
m_green=[]
me_green=[]
mo_green=[]
m_red=[]
me_red=[]
mo_red=[]
index=0
index1=0
index2=0
index3=0
index4=0
index5=0
index6=0
index7=0
index8=0
index9=0
index10=0
index11=0
for x in range(164):
  media_negro=mean(listan[index])
  mediana_negro=median(listan[index1])
  moda_negro=mode(listan[index8])
  media_azul=mean(listab[index2])
  mediana_azul=median(listab[index3])
  moda_azul=mode(listab[index9])
  media_green=mean(listag[index4])
  mediana_green=median(listag[index5])
  moda_green=mode(listag[index10])
  media_red=mean(listar[index6])
  mediana_red=median(listar[index7])
  moda_red=mode(listar[index11])
  index +=1
  index1 +=1
  index2 +=1
  index3 +=1
  index4 +=1
  index5 +=1
  index6 +=1
  index7 +=1
  index8 +=1
  index9 +=1
  index10 +=1
  index11 +=1

  m_negro.append(media_negro)
  me_negro.append(mediana_negro)
  mo_negro.append(moda_negro)
  m_azul.append(media_azul)
  me_azul.append(mediana_azul)
  mo_azul.append(moda_azul)
  m_green.append(media_green)
  me_green.append(mediana_green)
  mo_green.append(moda_green)
  m_red.append(media_red)
  me_red.append(mediana_red)
  mo_red.append(moda_red)

# %%
import pandas as pd
df = pd.DataFrame()
#id = ids
media_negro = m_negro
mediana_negro=me_negro
moda_negro=mo_negro
media_azul = m_azul
mediana_azul=me_azul
moda_azul=mo_azul
media_green = m_green
mediana_green=me_green
moda_green=mo_green
media_red = m_red
mediana_red=me_red
moda_red=mo_red
#df['id_i'] = ids
df['m_negrot_i'] = media_negro
df['me_negrot_i'] = mediana_negro
df['mo_negrot_i'] = moda_negro
df['m_azult_i'] = media_azul
df['me_azult_i'] = mediana_azul
df['mo_azult_i'] = moda_azul
df['m_verdet_i'] = media_green
df['me_verdet_i'] = mediana_green
df['mo_verdet_i'] = moda_green
df['m_rojot_i'] = media_red
df['me_rojot_i'] = mediana_red
df['mo_rojot_i'] = moda_red

df
# Out:
#      m_negrot_i  me_negrot_i  mo_negrot_i  m_azult_i  me_azult_i  mo_azult_i  \
# 0     83.521840         73.0           71  80.329645        63.0          61
# 1     82.657643         72.0           71  79.520482        62.0          62
# 2     81.691616         72.0           71  78.613405        62.0          61
# 3     80.650928         72.0           71  77.574563        62.0          64
# 4     73.214183         68.0           71  69.941183        57.0          61
# ..          ...          ...          ...        ...         ...         ...
# 159   44.553391         37.0           36  22.808963        17.0          14
# 160   44.509875         37.0           36  23.027740        17.0          17
# 161   45.874413         37.0           35  23.903609        17.0          14
# 162   45.521251         37.0           35  23.879606        17.0          17
# 163   46.213432         38.0           35  23.832395        17.0          14
#
# ...

# %%
df.to_excel('colormarca1.xlsx')
